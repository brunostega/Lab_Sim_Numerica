# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
import scipy.optimize as opt
from mpl_toolkits.mplot3d import Axes3D

# %%
file=open('crossover1/Search_L_circle.dat')
L=np.loadtxt(file, delimiter=",", usecols=[ 2], unpack=True)
indiv=np.linspace(50,500, 10)
P_m=np.linspace(0.1,0.37,10)

loss=np.zeros((10,10))
for i in range(10):
    for j in range(10):
        loss[i][j]=L[i*10+j]
loss_min, loss_max=loss.min(), loss.max()
fig, ax = plt.subplots()
pcm=ax.pcolormesh(P_m, indiv, loss,cmap='RdBu',vmin=loss_min, vmax=loss_max)
fig.colorbar(pcm,ax=ax)
plt.show()
# Out:
# <ipython-input-2-8c65703bd1d2>:12: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm=ax.pcolormesh(P_m, indiv, loss,cmap='RdBu',vmin=loss_min, vmax=loss_max)

# %%
file=open('crossover1/Search_L_square.dat')
L=np.loadtxt(file, delimiter=",", usecols=[ 2], unpack=True)
indiv=np.linspace(50,500, 10)
P_m=np.linspace(0.1,0.37,10)

loss=np.zeros((10,10))
for i in range(10):
    for j in range(10):
        loss[i][j]=L[i*10+j]
loss_min, loss_max=loss.min(), loss.max()
fig, ax = plt.subplots()
pcm=ax.pcolormesh(P_m, indiv, loss,cmap='RdBu',vmin=loss_min, vmax=loss_max)
fig.colorbar(pcm,ax=ax)
plt.show()
# Out:
# <ipython-input-3-9f6db8922981>:12: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm=ax.pcolormesh(P_m, indiv, loss,cmap='RdBu',vmin=loss_min, vmax=loss_max)

# %%
file=open('crossover2/Search_L_circle.dat')
L=np.loadtxt(file, delimiter=",", usecols=[ 3], unpack=True)
N_grid=8
N_exp=6
indiv=np.arange(50,50*(N_grid+1), 50)
P_m=np.arange(0.1,0.03*(N_grid+1),0.03)
loss=np.zeros((N_grid,N_grid, N_exp))
for i in range(N_grid):
    for j in range(N_grid):
        for k in range(N_exp):
            loss[i][j][k]=L[i*N_grid+j*N_grid+k]
loss_min, loss_max=loss.min(), loss.max()

print(len(indiv))
Min_exp=np.zeros(N_exp)
for i in range(N_exp):
    Min_exp[i]=loss[:][:][i].min()
print(Min_exp)
fig, ax = plt.subplots()
pcm=ax.pcolormesh(P_m, indiv, loss[:][:][5],cmap='RdBu',vmin=loss_min, vmax=loss_max)
fig.colorbar(pcm,ax=ax)
plt.show()
# Out:
# 8
# [14.1955 14.1955 14.1955 13.2379 13.1868 13.1868]
# <ipython-input-4-6eb9f45d5e53>:20: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm=ax.pcolormesh(P_m, indiv, loss[:][:][5],cmap='RdBu',vmin=loss_min, vmax=loss_max)

# %%
file=open('crossover2/Search_L_square.dat')
L=np.loadtxt(file, delimiter=",", usecols=[ 3], unpack=True)
N_grid=8
N_exp=6
indiv=np.arange(50,50*(N_grid+1), 50)
P_m=np.arange(0.1,0.03*(N_grid+1),0.03)
loss=np.zeros((N_grid,N_grid, N_exp))
for i in range(N_grid):
    for j in range(N_grid):
        for k in range(N_exp):
            loss[i][j][k]=L[i*N_grid+j*N_grid+k]
loss_min, loss_max=loss.min(), loss.max()

print(len(indiv))
Min_exp=np.zeros(N_exp)
for i in range(N_exp):
    Min_exp[i]=loss[:][:][i].min()
print(Min_exp)
fig, ax = plt.subplots()
pcm=ax.pcolormesh(P_m, indiv, loss[:][:][5],cmap='RdBu',vmin=loss_min, vmax=loss_max)
fig.colorbar(pcm,ax=ax)
plt.show()
# Out:
# 8
# [7.6673 7.6673 7.6673 7.6673 7.6673 7.6673]
# <ipython-input-5-27a23e5d4db7>:20: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm=ax.pcolormesh(P_m, indiv, loss[:][:][5],cmap='RdBu',vmin=loss_min, vmax=loss_max)
