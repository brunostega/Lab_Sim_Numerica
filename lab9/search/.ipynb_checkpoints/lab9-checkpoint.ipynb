# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
import scipy.optimize as opt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Square

# %%
file=open('square_pos.dat')
x,y=np.loadtxt(file, delimiter=",", usecols=[0,1], unpack=True)

file=open('order_square.dat')
order=np.loadtxt(file, delimiter=",", usecols=[0], unpack=True, dtype="int")


fig, ax=plt.subplots(nrows=1, ncols=3, figsize=(15,4))
ax[0].plot(x,y, '.')
ax[0].set_title("point in square")
ax[1].plot(x,y, '.-')
ax[1].set_title("casual connection")
ax[2].plot(x[order-1],y[order-1], '.-')
ax[2].set_title("connection after alghoritm")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-273f8e890bf1> in <module>
#       2 x,y=np.loadtxt(file, delimiter=",", usecols=[0,1], unpack=True)
#       3
# ----> 4 file=open('order_square.dat')
#       5 order=np.loadtxt(file, delimiter=",", usecols=[0], unpack=True, dtype="int")
#       6
#
# FileNotFoundError: [Errno 2] No such file or directory: 'order_square.dat'

# %%
file=open('square_pos.dat')
x,y=np.loadtxt(file, delimiter=",", usecols=[0,1], unpack=True)

file=open('order_square.dat')
order=np.loadtxt(file, delimiter=",", usecols=[0], unpack=True, dtype="int")


fig, ax=plt.subplots(nrows=1, ncols=3, figsize=(15,4))
ax[0].plot(x,y, '.')
ax[0].set_title("point in square")
ax[1].plot(x,y, '.-')

ax[1].set_title("casual connection")
ax[2].plot(x[order-1],y[order-1], '.-')
ax[2].set_title("connection after alghoritm")
plt.show()

# %%
file=open('L_square.dat')
gen,best_L, ave_L=np.loadtxt(file, delimiter=",", usecols=[0,1, 2], unpack=True)

plt.figure(figsize=(6,6))
plt.plot(gen, best_L, '.-')
plt.plot(gen, ave_L, '.-')
plt.title("fitness function")
plt.xlabel("# generation")
plt.ylabel("L")
plt.show()

# %% [markdown]
# ## Circumference

# %%
file=open('circle_pos.dat')
xc,yc=np.loadtxt(file, delimiter=",", usecols=[0,1], unpack=True)

file=open('order_circle.dat')
orderc=np.loadtxt(file, delimiter=",", usecols=[0], unpack=True, dtype="int")


fig, ax=plt.subplots(nrows=1, ncols=3, figsize=(15,4))
ax[0].plot(xc,yc, '.')
ax[0].set_title("point on a circumference")
ax[1].plot(xc,yc, '.-')
ax[1].set_title("casual connection")
ax[2].plot(xc[orderc-1],yc[orderc-1], '.-')
ax[2].set_title("connection after alghoritm")
plt.show()

# %%
file=open('L_circle.dat')
gen,best_L, ave_L=np.loadtxt(file, delimiter=",", usecols=[0,1, 2], unpack=True)

plt.figure(figsize=(6,6))
plt.plot(gen, best_L, '.-')
plt.plot(gen, ave_L, '.-')
plt.title("fitness function")
plt.xlabel("# generation")
plt.ylabel("L")
plt.show()
